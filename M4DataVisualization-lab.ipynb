# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Data Visualization Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be focusing on the visualization of data.
#
# The data set will be presented to you in the form of a RDBMS.
#
# You will have to use SQL queries to extract the data.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# *   Visualize the distribution of data.
#
# *   Visualize the relationship between two features.
#
# *   Visualize composition of data.
#
# *   Visualize comparison of data.

# %% [markdown]
# <hr>

# %% [markdown]
# # Hands-on Lab

# %% [markdown]
# ## Visualizing distribution of data

# %% [markdown]
# ### Histograms

# %% [markdown]
# Plot a histogram of `ConvertedComp.`

# %%
# your code goes here
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['ConvertedComp'].hist( bins=30, figsize=(5,5) )
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Box Plots

# %% [markdown]
# Plot a box plot of `Age.`

# %%
# your code goes here

df.boxplot(column=['Age'], figsize=(3,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Visualizing relationships in data

# %% [markdown]
# ### Scatter Plots

# %% [markdown]
# Create a scatter plot of `Age` and `WorkWeekHrs.`

# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt

df.plot(kind='scatter', x='Age', y='WorkWeekHrs', figsize=(10, 6), color='darkblue')

plt.title('Scatter Plot')
plt.xlabel('Age')
plt.ylabel('Work week hrs')

plt.show()

# %% [markdown]
# ### Bubble Plots

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

sns.set_context("talk", font_scale=1.1)
plt.figure(figsize=(10, 6))
sns.scatterplot(x="WorkWeekHrs",
                y="CodeRevHrs",
                data=df)
# Put the legend out of the figure
plt.legend(bbox_to_anchor=(1.01, 1), borderaxespad=0)
plt.xlabel("WorkWeekHrs")
plt.ylabel("CodeRevHrs")
plt.tight_layout()
plt.savefig("Bubble_plot_Seaborn_scatterplot.png",
            format='png', dpi=150)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df['Total'] = df.sum(axis=1)


df_DatabaseDesireNextYear = df.groupby('DatabaseDesireNextYear', axis=0).sum()

# note: the output of the groupby method is a `groupby' object. 
# we can not use it further until we apply a function (eg .sum())
print(type(df.groupby('DatabaseDesireNextYear', axis=0)))

df_DatabaseDesireNextYear.head()
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
# C:\Users\SAHITYA SUMAN\AppData\Local\Temp\ipykernel_14368\1431838485.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['Total'] = df.sum(axis=1)
#                                                     Respondent   CompTotal  \
# DatabaseDesireNextYear
# Cassandra                                               554953  14133236.0
# Cassandra;Couchbase                                      93703    862000.0
# Cassandra;Couchbase;DynamoDB                             24707         0.0
# Cassandra;Couchbase;DynamoDB;Elasticsearch               10759    130000.0
# Cassandra;Couchbase;DynamoDB;Elasticsearch;Fire...       20949    900000.0
#
#                                                     ConvertedComp  \
# DatabaseDesireNextYear
# ...

# %% [markdown]
# ## Visualizing composition of data

# %% [markdown]
# ### Pie Charts

# %% [markdown]
# Create a pie chart of the top 5 databases that respondents wish to learn next year. Label the pie chart with database names. Display percentages of each database on the pie chart.

# %%
DatabaseDesireNextYear_values = df.DatabaseDesireNextYear.value_counts().values
DatabaseDesireNextYear_lables = df.DatabaseDesireNextYear.value_counts().index

# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
plt.pie(DatabaseDesireNextYear_values[:5], labels=DatabaseDesireNextYear_lables[:5], autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2a62c5e8760>,
# ...
#  [Text(0.6609515594387231, 0.8792855259103952, 'Microsoft SQL Server'),
#   Text(-1.0228927539608834, 0.4045867198689548, 'PostgreSQL'),
#   Text(-0.5494562141459811, -0.9529416922017663, 'MongoDB'),
#   Text(0.45056229048472535, -1.0034907186382733, 'MySQL'),
#   Text(1.0303302819647553, -0.3852525276574161, 'PostgreSQL;Redis')],
#  [Text(0.36051903242112165, 0.4796102868602155, '29.48%'),
#   Text(-0.5579415021604818, 0.22068366538306625, '29.05%'),
#   Text(-0.29970338953417147, -0.5197863775645997, '16.29%'),
#   Text(0.24576124935530472, -0.5473585738026945, '13.79%'),
#   Text(0.5619983356171392, -0.2101377423585906, '11.39%')])

# %% [markdown]
# ### Stacked Charts

# %% [markdown]
# Create a stacked chart of median `WorkWeekHrs` and `CodeRevHrs` for the age group 30 to 35.

# %%
df_stacked = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv", usecols = ['WorkWeekHrs', 'CodeRevHrs','Age'])
print(df_stacked)
# Out:
#        WorkWeekHrs  CodeRevHrs   Age
# 0             80.0         NaN  22.0
# 1             32.0        12.0  23.0
# 2             40.0         5.0  28.0
# 3             40.0         NaN  26.0
# 4             45.0         5.0  29.0
# ...            ...         ...   ...
# 11393         40.0         NaN  36.0
# 11394         40.0         5.0  25.0
# 11395         40.0         5.0  34.0
# 11396         42.5         2.0  25.0
# 11397         80.0         1.0  30.0
#
# [11398 rows x 3 columns]

# %%
df_stacked = df_stacked.loc[(df_stacked['Age'] >= 30) & (df_stacked['Age'] <= 35)].reset_index().drop(columns=['index'])
df_stacked
# Out:
#       WorkWeekHrs  CodeRevHrs   Age
# 0             8.0         3.0  31.0
# 1            40.0         2.0  34.0
# 2            40.0         2.0  32.0
# 3            42.0        15.0  34.0
# 4            40.0         2.0  33.0
# ...           ...         ...   ...
# 2936         42.0         4.0  32.0
# 2937         50.0         2.0  32.0
# 2938         56.0        14.0  32.0
# 2939         40.0         5.0  34.0
# 2940         80.0         1.0  30.0
#
# [2941 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
df_stacked.groupby(['CodeRevHrs','Age'])['WorkWeekHrs'].median().sort_values(ascending=False).unstack().plot(kind='bar', stacked=True, figsize=(25, 10))
plt.title('Stacked Chart of Median WorkWeekHrs and CodeRevHrs For The Age Group 30 to 35',
          loc='center',pad=30, fontsize=30, color='blue')
plt.xlabel('CodeRevHrs', fontsize = 20)
plt.ylabel('WorkWeekHrs', fontsize = 20)
plt.legend(bbox_to_anchor=(1, 1), shadow=True, ncol=1, title='Age')
plt.ylim(ymin=0)
labels, locations = plt.yticks()
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualizing comparison of data

# %% [markdown]
# ### Line Chart

# %% [markdown]
# Plot the median `ConvertedComp` for all ages from 45 to 60.

# %%
df_line = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv", usecols = ['ConvertedComp', 'Age'])
print(df_line)
# Out:
#        ConvertedComp   Age
# 0            61000.0  22.0
# 1            95179.0  23.0
# 2            90000.0  28.0
# 3           455352.0  26.0
# 4            65277.0  29.0
# ...              ...   ...
# 11393       130000.0  36.0
# 11394        19880.0  25.0
# 11395       105000.0  34.0
# 11396        80371.0  25.0
# 11397            NaN  30.0
#
# [11398 rows x 2 columns]

# %%
df_line = df_line.loc[(df_line['Age'] >= 25) & (df_line['Age'] <= 30)].reset_index().drop(columns=['index'])
df_line.dropna(inplace=True)
df_line
# Out:
#       ConvertedComp   Age
# 0           90000.0  28.0
# 1          455352.0  26.0
# 2           65277.0  29.0
# 3           20623.0  27.0
# 4          107000.0  27.0
# ...             ...   ...
# 4005         7724.0  26.0
# 4006        35518.0  26.0
# 4007        26586.0  26.0
# 4008        19880.0  25.0
# 4009        80371.0  25.0
#
# [4010 rows x 2 columns]

# %%
df_line = df_line.groupby('Age', axis=0).median()
df_line
# Out:
#       ConvertedComp
# Age
# 25.0        39714.0
# 26.0        43834.0
# 26.3        31403.0
# 26.5        68000.0
# 27.0        49620.0
# 28.0        51559.0
# 29.0        55674.0
# 29.5        12228.0
# 30.0        56376.0

# %%
df_line.plot(kind='line')

plt.title('Average Compensation Based on Age Groups')
plt.ylabel('Converted Compensation (Annual USD')
plt.xlabel('Age')

plt.show()

# %% [markdown]
# ### Bar Chart

# %% [markdown]
# #Create a horizontal bar chart using column `MainBranch.`

# %%
df2= df["MainBranch"].value_counts()
df2.plot.barh(title="Horizontal bar graph of column MainBranch",
             color={"green", "pink"})
# Out:
# <AxesSubplot:title={'center':'Horizontal bar graph of column MainBranch'}>

# %% [markdown]
# Close the database connection.

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
